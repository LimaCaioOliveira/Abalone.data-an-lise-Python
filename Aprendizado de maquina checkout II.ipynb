# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
file_path = "/content/abalone.data"
data = pd.read_csv(file_path, header=None)
data.head()
# Out:
#    0      1      2      3       4       5       6      7   8
# 0  M  0.455  0.365  0.095  0.5140  0.2245  0.1010  0.150  15
# 1  M  0.350  0.265  0.090  0.2255  0.0995  0.0485  0.070   7
# 2  F  0.530  0.420  0.135  0.6770  0.2565  0.1415  0.210   9
# 3  M  0.440  0.365  0.125  0.5160  0.2155  0.1140  0.155  10
# 4  I  0.330  0.255  0.080  0.2050  0.0895  0.0395  0.055   7

# %%
columns = ["Sex", "Length", "Diameter", "Height", "Whole_weight", "Shucked_weight",
           "Viscera_weight", "Shell_weight", "Rings"]
data = pd.read_csv(file_path, names=columns)

data.head()
# Out:
#   Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  Viscera_weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell_weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %%
print("Número de instâncias e variáveis:", data.shape)
print("\nVisualização inicial dos dados:\n", data.head())
print("\nDescrição estatística:\n", data.describe())

print("\nValores ausentes por coluna:\n", data.isnull().sum())

print("\nDistribuição de Sex:\n", data['Sex'].value_counts())

data = data.drop(columns=["Sex"])
# Out:
# Número de instâncias e variáveis: (4177, 9)
#
# Visualização inicial dos dados:
#    Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  Viscera_weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell_weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7
#
# Descrição estatística:
#              Length     Diameter       Height  Whole_weight  Shucked_weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# ...

# %%
data.hist(bins=15, figsize=(15, 10))
plt.suptitle("Variáveis numéricas")
plt.show()

plt.figure(figsize=(10, 8))
sns.heatmap(data.corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlações")
plt.show()

# %%
X = data.drop(columns=["Rings"])
y = data["Rings"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
model = LinearRegression()

model.fit(X_train, y_train)

y_pred = model.predict(X_test)

r2 = r2_score(y_test, y_pred)

from sklearn.metrics import mean_squared_error, r2_score, mean_squared_error
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error

rmse

print("R-squared (R²):", r2)
print("Root Mean Square Error (RMSE):", rmse)
# Out:
# R-squared (R²): 0.5150025424490756
# Root Mean Square Error (RMSE): 2.2192193506637916

# %% [markdown]
# O valor de R² indica a proporção de variabilidade na idade do abalone que o modelo consegue explicar.
# Um RMSE mais alto pode sugerir que o modelo tem dificuldade em prever a idade com precisão, possivelmente devido à baixa correlação entre variáveis independentes e a variável alvo.
